# %% [markdown]
# # Activity: Perform multiple linear regression
#
# By **Saddam Umer**

# %% [markdown]
# ## Introduction

# %% [markdown]
# As you have learned, multiple linear regression helps you estimate the linear relationship between one continuous dependent variable and two or more independent variables. For data science professionals, this is a useful skill because it allows you to compare more than one variable to the variable you're measuring against. This provides the opportunity for much more thorough and flexible analysis.
#
# For this activity, you will be analyzing a small business' historical marketing promotion data. Each row corresponds to an independent marketing promotion where their business uses TV, social media, radio, and influencer promotions to increase sales. They previously had you work on finding a single variable that predicts sales, and now they are hoping to expand this analysis to include other variables that can help them target their marketing efforts.
#
# To address the business' request, you will conduct a multiple linear regression analysis to estimate sales from a combination of independent variables. This will include:
#
# * Exploring and cleaning data
# * Using plots and descriptive statistics to select the independent variables
# * Creating a fitting multiple linear regression model
# * Checking model assumptions
# * Interpreting model outputs and communicating the results to non-technical stakeholders

# %% [markdown]
# ## Step 1: Imports

# %% [markdown]
# ### Import packages

# %% [markdown]
# Import relevant Python libraries and modules.

# %%
# Import libraries and modules.

### YOUR CODE HERE ### 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# ### Load dataset

# %% [markdown]
# `Pandas` was used to load the dataset `marketing_sales_data.csv` as `data`, now display the first five rows. The variables in the dataset have been adjusted to suit the objectives of this lab. As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

### YOUR CODE HERE ### 
data = pd.read_csv('Task-3-Dataset-marketing_sales_data-Course-5.csv')

# Display the first five rows.

### YOUR CODE HERE ### 
data.head(5)
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 0     Low   3.518070      2.293790      Micro   55.261284
# 1     Low   7.756876      2.572287       Mega   67.574904
# 2    High  20.348988      1.227180      Micro  272.250108
# 3  Medium  20.108487      2.728374       Mega  195.102176
# 4    High  31.653200      7.776978       Nano  273.960377

# %% [markdown]
# ## Step 2: Data exploration

# %% [markdown]
# ### Familiarize yourself with the data's features
#
# Start with an exploratory data analysis to familiarize yourself with the data and prepare it for modeling.
#
# The features in the data are:
#
# * TV promotional budget (in "Low," "Medium," and "High" categories)
# * Social media promotional budget (in millions of dollars)
# * Radio promotional budget (in millions of dollars)
# * Sales (in millions of dollars)
# * Influencer size (in "Mega," "Macro," "Micro," and "Nano" categories)

# %% [markdown]
# **Question:** What are some purposes of EDA before constructing a multiple linear regression model?

# %% [markdown]
# **Answere:** Some purposes of EDA before constructing a multiple linear regression model include understanding which variables are present, reviewing the distribution of features (such as minimum, mean, and maximum values), plotting the relationship between independent and dependent variables to visualize linear relationships, and identifying issues with the data, like incorrect or missing values.

# %% [markdown]
# ### Create a pairplot of the data
#
# Create a pairplot to visualize the relationship between the continous variables in `data`.

# %%
# Create a pairplot of the data.

### YOUR CODE HERE ### 
sns.pairplot(data)

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to [the content where creating a pairplot is demonstrated](https://www.coursera.org/learn/regression-analysis-simplify-complex-data-relationships/item/dnjWm).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the function in the `seaborn` library that allows you to create a pairplot showing the relationships between variables in the data.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `pairplot()` function from the `seaborn` library and pass in the entire DataFrame.
#
# </details>

# %% [markdown]
# **Question:** Which variables have a linear relationship with `Sales`? Why are some variables in the data excluded from the preceding plot?

# %% [markdown]
# **Answere:** Radio and Social Media both show linear relationships with Sales, making them potential independent variables in a multiple linear regression model. TV and Influencer are excluded from the plot as they are not numeric variables.

# %% [markdown]
# ### Calculate the mean sales for each categorical variable

# %% [markdown]
# There are two categorical variables: `TV` and `Influencer`. To characterize the relationship between the categorical variables and `Sales`, find the mean `Sales` for each category in `TV` and the mean `Sales` for each category in `Influencer`.

# %%
# Calculate the mean sales for each TV category. 

### YOUR CODE HERE ### 
tv_mean_sale = data.groupby('TV')['Sales'].mean() 


# Calculate the mean sales for each Influencer category. 

### YOUR CODE HERE ### 
infl_mean_sale = data.groupby('Influencer')['Sales'].mean() 


print(tv_mean_sale,'\n\n', infl_mean_sale)
# Out:
# TV
# High      300.853195
# Low        90.984101
# Medium    195.358032
# Name: Sales, dtype: float64
#
#  Influencer
# Macro    181.670070
# Mega     194.487941
# Micro    188.321846
# Nano     191.874432
# Name: Sales, dtype: float64

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Find the mean `Sales` when the `TV` promotion is `High`, `Medium`, or `Low`.
#
# Find the mean `Sales` when the `Influencer` promotion is `Macro`, `Mega`, `Micro`, or `Nano`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `groupby` operation in `pandas` to split an object (e.g., data) into groups and apply a calculation to each group.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# To calculate the mean `Sales` for each `TV` category, group by `TV`, select the `Sales` column, and then calculate the mean.
#
# Apply the same process to calculate the mean `Sales` for each `Influencer` category.
#
# </details>

# %% [markdown]
# **Question:** What do you notice about the categorical variables? Could they be useful predictors of `Sales`?

# %% [markdown]
# **Answere:** The average Sales for High TV promotions are noticeably higher than for Medium and Low TV promotions, suggesting TV could be a strong predictor of Sales. While the Influencer categories show different average Sales, the variation is minimal, indicating Influencer may be a weaker predictor. Further analysis can be done when fitting the multiple linear regression model.

# %% [markdown]
# ### Remove missing data
#
# This dataset contains rows with missing values. To correct this, drop all rows that contain missing data.

# %%
# Drop rows that contain missing data and update the DataFrame.

### YOUR CODE HERE ### 
data.dropna(axis=0, inplace=True)

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Use the `pandas` function that removes missing values.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `dropna()` function removes missing values from an object (e.g., DataFrame).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use `data.dropna(axis=0)` to drop all rows with missing values in `data`. Be sure to properly update the DataFrame.
#
# </details>

# %% [markdown]
# ### Clean column names

# %% [markdown]
# The `ols()` function doesn't run when variable names contain a space. Check that the column names in `data` do not contain spaces and fix them, if needed.

# %%
# Rename all columns in data that contain a space. 

### YOUR CODE HERE ### 
data.columns = ['TV', 'Radio', 'Social_Media', 'Influencer', 'Sales']

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# There is one column name that contains a space. Search for it in `data`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `Social Media` column name in `data` contains a space. This is not allowed in the `ols()` function.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `rename()` function in `pandas` and use the `columns` argument to provide a new name for `Social Media`.
#
# </details>

# %% [markdown]
# ## Step 3: Model building

# %% [markdown]
# ### Fit a multiple linear regression model that predicts sales
#
# Using the independent variables of your choice, fit a multiple linear regression model that predicts `Sales` using two or more independent variables from `data`.

# %%
# Define the OLS formula.

### YOUR CODE HERE ### 
formula = 'Sales ~ Radio + C(TV) '

# Create an OLS model.

### YOUR CODE HERE ### 
OLS = ols( formula=formula, data=data)


# Fit the model.

### YOUR CODE HERE ### 
model = OLS.fit()

# Save the results summary.

### YOUR CODE HERE ### 
result_summary = model.summary()

# Display the model results.

### YOUR CODE HERE ### 
result_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     1783.
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):          1.63e-288
# Time:                        08:11:29   Log-Likelihood:                -2714.0
# No. Observations:                 572   AIC:                             5436.
# Df Residuals:                     568   BIC:                             5453.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         218.5261      6.261     34.902      0.000     206.228     230.824
# C(TV)[T.Low]     -154.2971      4.929    -31.303      0.000    -163.979    -144.616
# C(TV)[T.Medium]   -75.3120      3.624    -20.780      0.000     -82.431     -68.193
# Radio               2.9669      0.212     14.015      0.000       2.551       3.383
# ==============================================================================
# Omnibus:                       61.244   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.077
# Skew:                           0.046   Prob(JB):                     0.000119
# Kurtosis:                       2.134   Cond. No.                         142.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to the content that discusses [model building](https://www.coursera.org/learn/regression-analysis-simplify-complex-data-relationships/lecture/zd74V/interpret-multiple-regression-coefficients) for linear regression.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `ols()` function imported earlier—which creates a model from a formula and DataFrame—to create an OLS model.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# You previously learned how to specify in `ols()` that a feature is categorical.
#
# Be sure the string names for the independent variables match the column names in `data` exactly.
#
# </details>

# %% [markdown]
# **Question:** Which independent variables did you choose for the model, and why?

# %% [markdown]
# **Answere:** TV and Radio were selected as independent variables due to their strong relationships with Sales, as seen in the preceding analysis. Social Media was excluded since it did not improve model performance and was correlated with Radio. Influencer was also excluded because it showed a weak relationship with Sales.

# %% [markdown]
# ### Check model assumptions

# %% [markdown]
# For multiple linear regression, there is an additional assumption added to the four simple linear regression assumptions: **multicollinearity**.
#
# Check that all five multiple linear regression assumptions are upheld for your model.

# %% [markdown]
# ### Model assumption: Linearity

# %% [markdown]
# Create scatterplots comparing the continuous independent variable(s) you selected previously with `Sales` to check the linearity assumption. Use the pairplot you created earlier to verify the linearity assumption or create new scatterplots comparing the variables of interest.

# %%
# Create a scatterplot for each independent variable and the dependent variable.

### YOUR CODE HERE ### 
sns.pairplot(data[['Radio','Sales']])

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Use the function in the `seaborn` library that allows you to create a scatterplot to display the values for two variables.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `scatterplot()` function in `seaborn`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Pass the independent and dependent variables in your model as the arguments for `x` and `y`, respectively, in the `scatterplot()` function. Do this for each continous independent variable in your model.
#
# </details>

# %% [markdown]
# **Question:** Is the linearity assumption met?

# %% [markdown]
# **Answere:** The linearity assumption is met for Radio, as shown by the clear linear relationship between Radio and Sales in the scatterplot. Although Social Media was not included in the model, it also seems to have a linear relationship with Sales.

# %% [markdown]
# ### Model assumption: Independence

# %% [markdown]
# The **independent observation assumption** states that each observation in the dataset is independent. As each marketing promotion (i.e., row) is independent from one another, the independence assumption is not violated.

# %% [markdown]
# ### Model assumption: Normality

# %% [markdown]
# Create the following plots to check the **normality assumption**:
#
# * **Plot 1**: Histogram of the residuals
# * **Plot 2**: Q-Q plot of the residuals

# %%
fig, [ ax1, ax2] = plt.subplots( figsize=(11,4), nrows=1,ncols= 2)

# Calculate the residuals.

### YOUR CODE HERE ### 
residual = model.resid

# Create a histogram with the residuals. 

### YOUR CODE HERE ### 
ax1.hist(residual)
ax1.set_xlabel('Residual')
ax1.set_title('Residuals Histogram')

# Create a Q-Q plot of the residuals.

### YOUR CODE HERE ### 
sm.qqplot(residual, line='s', ax = ax2)

ax2.set_title('Residuals Q-Q Plot')

plt.show()

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Access the residuals from the fit model object.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use `model.resid` to get the residuals from a fit model called `model`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# For the histogram, pass the residuals as the first argument in the `seaborn` `histplot()` function.
#
# For the Q-Q plot, pass the residuals as the first argument in the `statsmodels` `qqplot()` function.
#
# </details>

# %% [markdown]
# **Question:** Is the normality assumption met?

# %% [markdown]
# **Answere:** The normality assumption is met, as the histogram of the residuals shows an approximately normal distribution. Additionally, the Q-Q plot shows the residuals forming a straight line, further supporting this assumption.

# %% [markdown]
# ### Model assumption: Constant variance

# %% [markdown]
# Check that the **constant variance assumption** is not violated by creating a scatterplot with the fitted values and residuals. Add a line at $y = 0$ to visualize the variance of residuals above and below $y = 0$.

# %%
# Create a scatterplot with the fitted values from the model and the residuals.

### YOUR CODE HERE ### 
y_pred = model.predict(data[['TV','Influencer','Radio']])

fig = sns.scatterplot(x=y_pred,y=residual)

# Add a line at y = 0 to visualize the variance of residuals above and below 0.

### YOUR CODE HERE ### 
fig.axhline(0)

fig.set_title('Fitted Values VS Residuals')
fig.set_xlabel('Fitted Values')
fig.set_ylabel('Residuals')
plt.show()

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Access the fitted values from the model object fit earlier.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use `model.fittedvalues` to get the fitted values from a fit model called `model`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
#
# Call the `scatterplot()` function from the `seaborn` library and pass in the fitted values and residuals.
#
# Add a line to a figure using the `axline()` function.
#
# </details>

# %% [markdown]
# **Question:** Is the constant variance assumption met?

# %% [markdown]
# **Answere:** The constant variance assumption is met. Although the fitted values form distinct groups due to the strong influence of the categorical TV variable, the variance within each group is similarly distributed, indicating that this assumption holds true.

# %% [markdown]
# ### Model assumption: No multicollinearity

# %% [markdown]
# The **no multicollinearity assumption** states that no two independent variables ($X_i$ and $X_j$) can be highly correlated with each other.
#
# Two common ways to check for multicollinearity are to:
#
# * Create scatterplots to show the relationship between pairs of independent variables
# * Use the variance inflation factor to detect multicollinearity
#
# Use one of these two methods to check your model's no multicollinearity assumption.

# %%
# Create a pairplot of the data.

### YOUR CODE HERE ### 
sns.pairplot(data)

# %%
# Calculate the variance inflation factor (optional).

### YOUR CODE HERE ### 

from statsmodels.stats.outliers_influence import variance_inflation_factor

X = data[['Radio','Social_Media']]

vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

df_vif = pd.DataFrame(vif, index=X.columns, columns = ['VIF'])

# Display the VIF results.
df_vif
# Out:
#                    VIF
# Radio         5.170922
# Social_Media  5.170922

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Confirm that you previously created plots that could check the no multicollinearity assumption.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `pairplot()` function applied earlier to `data` plots the relationship between all continous variables  (e.g., between `Radio` and `Social Media`).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# The `statsmodels` library has a function to calculate the variance inflation factor called `variance_inflation_factor()`.
#
# When using this function, subset the data to only include the continous independent variables (e.g., `Radio` and `Social Media`). Refer to external tutorials on how to apply the variance inflation factor function mentioned previously.
#
#
# </details>

# %% [markdown]
# **Question 8:** Is the no multicollinearity assumption met?

# %% [markdown]
# **Answere:** The no multicollinearity assumption is met in the preceding model since it only includes one continuous independent variable. However, if both Radio and Social Media were included, there would be a moderate linear relationship between them, leading to multicollinearity issues. The variance inflation factor (VIF) of 5.17 for each variable would indicate significant multicollinearity, making it problematic to include both in the model.

# %% [markdown]
# ## Step 4: Results and evaluation

# %% [markdown]
# ### Display the OLS regression results
#
# If the model assumptions are met, you can interpret the model results accurately.
#
# First, display the OLS regression results.

# %%
# Display the model results summary.

### YOUR CODE HERE ### 
result_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     1783.
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):          1.63e-288
# Time:                        08:11:29   Log-Likelihood:                -2714.0
# No. Observations:                 572   AIC:                             5436.
# Df Residuals:                     568   BIC:                             5453.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         218.5261      6.261     34.902      0.000     206.228     230.824
# C(TV)[T.Low]     -154.2971      4.929    -31.303      0.000    -163.979    -144.616
# C(TV)[T.Medium]   -75.3120      3.624    -20.780      0.000     -82.431     -68.193
# Radio               2.9669      0.212     14.015      0.000       2.551       3.383
# ==============================================================================
# Omnibus:                       61.244   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.077
# Skew:                           0.046   Prob(JB):                     0.000119
# Kurtosis:                       2.134   Cond. No.                         142.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question:** What is your interpretation of the model's R-squared?

# %% [markdown]
# **Answere:** The model's R-squared value of 0.904 indicates that 90.4% of the variation in Sales can be explained by the independent variables TV and Radio. This high R-squared value suggests that the model is a strong predictor of Sales, effectively capturing the relationship between the promotional budgets for TV and Radio and the resulting Sales figures.

# %% [markdown]
# ### Interpret model coefficients

# %% [markdown]
# With the model fit evaluated, you can look at the coefficient estimates and the uncertainty of these estimates.
#
# Again, display the OLS regression results.

# %%
# Display the model results summary.

### YOUR CODE HERE ### 
result_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     1783.
# Date:                Wed, 25 Sep 2024   Prob (F-statistic):          1.63e-288
# Time:                        08:11:29   Log-Likelihood:                -2714.0
# No. Observations:                 572   AIC:                             5436.
# Df Residuals:                     568   BIC:                             5453.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         218.5261      6.261     34.902      0.000     206.228     230.824
# C(TV)[T.Low]     -154.2971      4.929    -31.303      0.000    -163.979    -144.616
# C(TV)[T.Medium]   -75.3120      3.624    -20.780      0.000     -82.431     -68.193
# Radio               2.9669      0.212     14.015      0.000       2.551       3.383
# ==============================================================================
# Omnibus:                       61.244   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.077
# Skew:                           0.046   Prob(JB):                     0.000119
# Kurtosis:                       2.134   Cond. No.                         142.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Question:** What are the model coefficients?

# %% [markdown]
# **Answere:**

# %% [markdown]
# **Question:** How would you write the relationship between `Sales` and the independent variables as a linear equation?

# %% [markdown]
# **Answere:** When predicting Sales using TV and Radio, the coefficients are:
# * $\beta_{0} =  218.5261$
# * $\beta_{TVLow}= -154.2971$
# * $\beta_{TVMedium} = -75.3120$
# * $\beta_{Radio} =  2.9669$

# %% [markdown]
# **Question:** What is your intepretation of the coefficient estimates? Are the coefficients statistically significant?

# %% [markdown]
# **Answere:** The relationship between Sales and the independent variables can be expressed as:
#
# `Sales = 218.5261 + (−154.2971 * X TV Low) + (−75.3120 * X TV Medium) + (2.9669 * X Radio)`

# %% [markdown]
# **Question:** Why is it important to interpret the beta coefficients?

# %% [markdown]
# **Answere:** Beta coefficients provide insights into the effect size and direction of each independent variable on Sales, translating into actionable insights for decision-making.

# %% [markdown]
# **Question:** What are you interested in exploring based on your model?

# %% [markdown]
# **Answere:**  Potential areas to explore include estimating Sales based on various TV and Radio promotional budgets and creating additional visualizations, like seaborn's `regplot()`, to illustrate results.

# %% [markdown]
# **Question:** Do you think your model could be improved? Why or why not? How?

# %% [markdown]
# **Answere:** The model could benefit from a more detailed analysis of TV promotions by including more categories or specific budgets. Adding variables such as campaign location or seasonality could further enhance model accuracy.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **What are the key takeaways from this lab?**
#
# This lab highlights the effectiveness of multiple linear regression as a tool for estimating a continuous dependent variable from several independent variables. It emphasizes the importance of exploratory data analysis in selecting relevant features, both numeric and categorical. Additionally, it underlines the necessity of testing model assumptions and refining variable selection to enhance model accuracy.
#
#
#
# **What results can be presented from this lab?**
#
# The analysis shows that higher TV promotional budgets are associated with significantly higher sales compared to medium and low budgets. The model estimates that switching from a high to a medium TV promotional budget results in a reduction of \\$75.3120 million in sales, while switching to a low budget decreases sales by \\$154.297 million. The positive coefficient for the radio promotional budget indicates that an increase of \\$1 million in radio spending is projected to lead to a \\$2.9669 million increase in sales. All coefficients are statistically significant, providing confidence in the model's findings.
#
#
# **How would you frame your findings to external stakeholders?**
#
# To external stakeholders, I would emphasize that high TV promotional budgets have a substantial and positive impact on sales, making them a crucial area for investment. The model suggests that reducing the TV budget from high to medium or low significantly decreases sales, highlighting the value of maintaining strong TV promotions. Additionally, investing in radio promotions can further enhance sales. I would recommend that stakeholders prioritize high TV promotional budgets and consider radio advertising as a complementary strategy to maximize overall sales performance.

# %% [markdown]
# #### **References**
#
# Saragih, H.S. (2020). [*Dummy Marketing and Sales Data*](https://www.kaggle.com/datasets/harrimansaragih/dummy-advertising-and-sales-data).

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
